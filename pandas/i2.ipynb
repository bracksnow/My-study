# %%
import pandas as pd

# %%
df = pd.read_csv('./pandas-master/data/friend_list.csv')

# %%
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern

# %%
df.tail(2)
# Out:
#     name  age      job
# 4  Brian   45  manager
# 5  Chris   25   intern

# %%
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern

# %%
df = pd.read_csv('./pandas-master/data/friend_list.csv', header = None)

# %%
df
# Out:
#        0    1          2
# 0   name  age        job
# 1   John   20    student
# 2  Jenny   30  developer
# 3   Nate   30    teacher
# 4  Julia   40    dentist
# 5  Brian   45    manager
# 6  Chris   25     intern

# %%
df = pd.read_csv('./pandas-master/data/friend_list.csv')

# %%
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern

# %%
df = pd.read_csv('./pandas-master/data/friend_list.csv', header = None)

# %%
df
# Out:
#        0    1          2
# 0   name  age        job
# 1   John   20    student
# 2  Jenny   30  developer
# 3   Nate   30    teacher
# 4  Julia   40    dentist
# 5  Brian   45    manager
# 6  Chris   25     intern

# %%
df.columns = ['name','age','job']

# %%
df
# Out:
#     name  age        job
# 0   name  age        job
# 1   John   20    student
# 2  Jenny   30  developer
# 3   Nate   30    teacher
# 4  Julia   40    dentist
# 5  Brian   45    manager
# 6  Chris   25     intern

# %%
df = pd.read_csv('./pandas-master/data/friend_list.csv', header = None)

# %%
df = pd.read_csv('./pandas-master/data/friend_list.csv', header = None, names = ['name','age','job'])

# %%
# Out:
#     name  age        job
# 0   name  age        job
# 1   John   20    student
# 2  Jenny   30  developer
# 3   Nate   30    teacher
# 4  Julia   40    dentist
# 5  Brian   45    manager
# 6  Chris   25     intern
